# %% [markdown]
# <h3> Introduction to Matplotlib Package</h3>
# In this section we will learn about matplotlib package that helps you to generate plots, histograms,
# power spectra, bar charts, errorcharts, scatterplots, etc.
# <h3> References </h3>
# <a href="https://matplotlib.org/users/pyplot_tutorial.html"> Matplotlib Tutorial - I </a><br>
# <a href="http://www.python-course.eu/matplotlib.php"> Matplotlib Tutorial - II </a><br>
# <a href="https://github.com/matplotlib/AnatomyOfMatplotlib"> Matplotlib Tutorial - III </a><br>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([1,2,3,4],color='lightblue', linewidth=12)
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot?

# %% [markdown]
# If you provide a single list or array to the plot() command, matplotlib assumes it is a sequence of y values, and automatically generates the x values for you. Since python ranges start with 0, the default x vector has the same length as y but starts with 0. Hence the x data are [0,1,2,3].

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'ro')  # default is "-" solid line
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# The axis() command in the example above takes a list of [xmin, xmax, ymin, ymax] and specifies the viewport of the axes.

# %% [markdown]
# Exercise: Repeat the above plot by creating y values using np.random.randint(1, 20, size=4)

# %%
plt.plot([1,2,3,4], np.random.randint(1, 20, size=4))
plt.ylabel('random numbers')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)
# multiple plots 
# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
days = list(range(1,9))
celsius_min = [19.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]
celsius_max = [24.8, 28.9, 31.3, 33.0, 34.9, 35.6, 38.4, 39.2]
plt.xlabel('Day')
plt.ylabel('Degrees Celsius')
plt.plot(days, celsius_min,
         days, celsius_min, "oy",
         days, celsius_max, 
         days, celsius_max, "or")
plt.show()

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

# %%
plt.scatter?

# %%
plt.scatter('a', 'b', c='c', s='d', data=data) #color mapping from data['c'] and size: data['d']
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
x = np.arange(100)
y = x
color = x
plt.scatter(x, y, c=color)
plt.show()

# %% [markdown]
# #### Color Maps
# Change colormaps
# https://matplotlib.org/examples/color/colormaps_reference.html

# %%
x = np.arange(100)
y = x
color = x
plt.scatter(x, y, c=color, cmap='Greys')
plt.show()

# %%
x = np.arange(100)
y = x
color = x
plt.scatter(x, y, c=color, cmap='YlOrRd') 
plt.show()

# %%
x = np.arange(100)
y = x
color = x
plt.scatter(x, y, c=color, cmap='YlOrRd_r') 
plt.colorbar()
plt.show()

# %%
x = [1,2,3,4]
y = [1,4,9,16]
#sz = [8, 16, 32, 64]
sz = [8, 32, 128, 256]  #area
plt.scatter(x, y, color='Blue', s=sz)  
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# Exercise: For the above plot change the color of the circle based on the size.

# %%
x = [1,2,3,4]
y = [1,4,9,16]
#sz = [8, 16, 32, 64]
sz = [8, 32, 128, 256]  #area
plt.scatter(x, y, c=sz, s=sz)  
plt.axis([0, 6, 0, 20])
plt.show()

# %%
# multiple subplots 
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(figsize=(6, 4)) # size of the figure where we will have multiple sub plots
plt.subplot(211) # numrows, numcols, fignum (1 to 4) 
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
# multiple subplots 
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(figsize=(6, 4)) # size of the figure where we will have multiple sub plots
plt.subplot(221) # numrows, numcols, fignum (1 to 4) 
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(224)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %% [markdown]
# Exercise: Modify the above code to have the following plot.
# ![image.png](attachment:image.png)

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(figsize=(6, 4)) # size of the figure where we will have multiple sub plots
plt.subplot(221) # numrows, numcols, fignum (1 to 4) 
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')
plt.subplot(222)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')
plt.subplot(223)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.subplot(224)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
X = [ (2,1,1), (2,3,4), (2,3,5), (2,3,6) ]
#X = [ (2,1,1), (2,1,2)]
plt.figure(figsize=(12, 6))
for nrows, ncols, plot_number in X:
    plt.subplot(nrows, ncols, plot_number)
plt.show()

# %% [markdown]
# #### Working with text
# The text() command can be used to add text in an arbitrary location, and the xlabel(), ylabel() and title() are used to add text in the indicated locations. Any text element can use math text. You should use raw strings (precede the quotes with an 'r'), and surround the math text with dollar signs ($), as in TeX.

# %%
plt.text?

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, _ = plt.hist(x, 50, normed=1)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %% [markdown]
# #### Annotating text
# A common use for text is to annotate some feature of the plot, and the annotate() method provides helper functionality to make annotations easy. In an annotation, there are two points to consider: the location being annotated represented by the argument xy and the location of the text xytext. Both of these arguments are (x,y) tuples.

# %%
t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# Exercise: Modify the above code to annotate the local min.

# %%
t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
plt.plot(t, s, lw=2)

plt.annotate('local min', xy=(1.5, -1), xytext=(2, -1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %%
xlist = np.linspace(-3.0, 3.0, 100)
ylist = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(xlist, ylist)

# %%
Z = np.sqrt(X**2 + Y**2)
plt.figure()
cp = plt.contourf(X, Y, Z)
#cp = plt.contourf(X, Y, Z,cmap='YlOrRd')
plt.colorbar(cp)
plt.title('Filled Contours Plot')
plt.xlabel('x (cm)')
plt.ylabel('y (cm)')
plt.show()

# %% [markdown]
# Exercise: Modify the contour code to create a non-filled contour plot like:
# ![image.png](attachment:image.png)
#
# Hint: Use plt.contour() and plt.clabel()

# %%
Z = np.sqrt(X**2 + Y**2)
plt.figure()
cp = plt.contour(X, Y, Z)
#cp = plt.contourf(X, Y, Z,cmap='YlOrRd')
plt.clabel(cp)

plt.title('Contour Plot')
plt.xlabel('x (cm)')
plt.ylabel('y (cm)')
plt.show()

# %% [markdown]
# #### plt.imshow()
# Using interpolation

# %%
A = np.random.rand(5, 5)
plt.imshow?

# %%
plt.figure(1)
plt.imshow(A, interpolation='bilinear')
#plt.imshow(A, interpolation='none')
plt.grid(True)
plt.show()

# %% [markdown]
# Exercise: Repeat the above plot with a different colormap

# %%
plt.figure(1)
plt.imshow(A, interpolation='bilinear', cmap='YlOrRd_r')
plt.grid(True)
plt.show()

# %%
plt.figure(1)
plt.imshow(A, interpolation='bilinear', cmap='YlOrRd')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Plot Heat Map - Correlation Matrix

# %%
import pandas as pd, pandas_datareader.data as data
from datetime import datetime as dt

# %%
# give a sample start date and stocks as input
start = dt(2016,10,31)
stocks = ['FB', 'AMZN', 'GOOG', 'NFLX', 'GLD']

# %%
# read stock closing values from Google
stocks_data = data.DataReader(stocks, 'yahoo', start)['Close']
stocks_data.head()
# Out:
#                    AMZN          FB         GLD         GOOG        NFLX
# Date
# 2018-02-15  1461.760010  179.960007  128.380005  1089.520020  280.269989
# 2018-02-14  1451.050049  179.520004  128.229996  1069.699951  266.000000
# 2018-02-13  1414.510010  173.149994  126.080002  1052.099976  258.269989
# 2018-02-12  1386.229980  176.410004  125.370003  1051.939941  257.950012
# 2018-02-09  1339.599976  176.110001  124.769997  1037.780029  249.470001

# %%
stocks_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 326 entries, 2018-02-15 to 2016-10-31
# Data columns (total 5 columns):
# AMZN    326 non-null float64
# FB      326 non-null float64
# GLD     326 non-null float64
# GOOG    326 non-null float64
# NFLX    326 non-null float64
# dtypes: float64(5)
# memory usage: 15.3 KB

# %%
# calculate percentage change using pandas functions pct_change()
stocks_pct_change = stocks_data.pct_change()
stocks_pct_change.head()
# Out:
#                 AMZN        FB       GLD      GOOG      NFLX
# Date
# 2018-02-15       NaN       NaN       NaN       NaN       NaN
# 2018-02-14 -0.007327 -0.002445 -0.001168 -0.018192 -0.050915
# 2018-02-13 -0.025182 -0.035484 -0.016767 -0.016453 -0.029060
# 2018-02-12 -0.019993  0.018828 -0.005631 -0.000152 -0.001239
# 2018-02-09 -0.033638 -0.001701 -0.004786 -0.013461 -0.032875

# %%
# calculate Pearson Correlation using pandas function corr()
corr_stocks = stocks_pct_change.corr()
corr_stocks
# Out:
#           AMZN        FB       GLD      GOOG      NFLX
# AMZN  1.000000  0.570458  0.005389  0.638357  0.502352
# FB    0.570458  1.000000 -0.026785  0.697873  0.470458
# GLD   0.005389 -0.026785  1.000000  0.021348  0.058594
# GOOG  0.638357  0.697873  0.021348  1.000000  0.507983
# NFLX  0.502352  0.470458  0.058594  0.507983  1.000000

# %%
plt.figure(figsize=(12, 10))
plt.imshow(corr_stocks, cmap='RdYlGn', interpolation='none', aspect='auto')
plt.colorbar()
plt.xticks(range(len(corr_stocks)), corr_stocks.columns, rotation='vertical')
plt.yticks(range(len(corr_stocks)), corr_stocks.columns);
plt.suptitle('Stock Correlations Heat Map', fontsize=15, fontweight='bold')
plt.show()
