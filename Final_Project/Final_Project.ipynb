# %% [markdown]
# Name: Hrishikesh Gadkari
# Final Report

# %%
import pandas as pd
from bokeh.io import show
from bokeh.models import (
    ColumnDataSource,
    HoverTool,
    LogColorMapper
)
from bokeh.palettes import Viridis6 as palette
from bokeh.plotting import figure

#from bokeh.sampledata.us_counties import data as counties
#from bokeh.sampledata.unemployment import data as unemployment

palette.reverse()
df = pd.read_csv('accidents_2005_to_2007.csv')
df = df.fillna('')
#counties = {
 #   code: county for code, county in df.items() if county["state"] == "tx"
#}
county_xs=[]
county_ys=[]
county_rates=[]
for nei in df['Longitude']: 
    county_xs.append(nei)
for bld in df['Latitude']: 
    county_ys.append(bld)
for con in df['Number_of_Casualties']:
    county_rates.append(con)
    

#county_names = [county['name'] for county in counties.values()]

color_mapper = LogColorMapper(palette=palette)

source = ColumnDataSource(data=dict(
    x=county_xs,
    y=county_ys,
    casualties=county_rates,
))

TOOLS = "pan,wheel_zoom,reset,hover,save"

p = figure(
    title="Texas Unemployment, 2009", tools=TOOLS,
    x_axis_location=None, y_axis_location=None
)
p.grid.grid_line_color = None

p.patches('x', 'y', source=source,
          fill_color={'field': 'casualties', 'transform': color_mapper},
          fill_alpha=0.7, line_color="white", line_width=0.5)

hover = p.select_one(HoverTool)
hover.point_policy = "follow_mouse"
hover.tooltips = [
    
    ("Casualties)", "@casualties"),
    ("(Long, Lat)", "($x, $y)"),
]
# Out:
# C:\Users\GADKARI\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import numpy as np
ctrl_rate_data = np.genfromtxt('accidents_2005_to_2007.csv', skip_header=1, delimiter=',')
f99 = ctrl_rate_data[:, 8]

# %%
print("The number of casualties reported per accident for the years 2005-2007: ", len(f99) )

print("The total number of casualties for the years 2005-2007: ", np.sum(f99))
# Out:
# The number of casualties reported per accident for the years 2005-2007:  570011
# The total number of casualties for the years 2005-2007:  777201.0

# %%
import matplotlib.mlab as mlab   # for plotting pdf
import matplotlib.pyplot as plt

histT, bin_edges = np.histogram(f99, bins=20, density=True)
plt.hist(f99, normed=True, bins=bin_edges)
xmin, xmax = plt.xlim()


x = np.linspace(xmin, xmax, 50)
p = mlab.normpdf(x, np.mean(f99), np.std(f99))

plt.plot(x, p, 'r', linewidth=2)
plt.show()

# %%
ctrl_rate_data1 = np.genfromtxt('accidents_2009_to_2011.csv', skip_header=1, delimiter=',')
f100 = ctrl_rate_data1[:, 8]

# %%
print("The number of casualties reported per accident for the years 2009-2011: ", len(f100) )

print("The total number of casualties for the years 2009-2011: ", np.sum(f100))
# Out:
# The number of casualties reported per accident for the years 2009-2011:  469442
# The total number of casualties for the years 2009-2011:  634744.0

# %%
histT, bin_edges = np.histogram(f100, bins=20, density=True)
plt.hist(f100, normed=True, bins=bin_edges)
xmin, xmax = plt.xlim()


x = np.linspace(xmin, xmax, 50)
p = mlab.normpdf(x, np.mean(f100), np.std(f100))

plt.plot(x, p, 'r', linewidth=2)
plt.show()

# %%
ctrl_rate_data2 = np.genfromtxt('accidents_2012_to_2014.csv', skip_header=1, delimiter=',')
f101 = ctrl_rate_data2[:, 8]

# %%
print("The number of accidents recorded for the years 2012-2014: ", len(f101) )

print("The total number of casualties for the years 2012-2014: ", np.sum(f101))
# Out:
# The number of accidents recorded for the years 2012-2014:  464697
# The total number of casualties for the years 2012-2014:  620101.0

# %%
histT, bin_edges = np.histogram(f101, bins=20, density=True)
plt.hist(f101, normed=True, bins=bin_edges)
xmin, xmax = plt.xlim()


x = np.linspace(xmin, xmax, 50)
p = mlab.normpdf(x, np.mean(f101), np.std(f101))

plt.plot(x, p, 'r', linewidth=2)
plt.show()

# %%
#data cleaning
import seaborn as sns
import pandas as pd
data = pd.read_csv('accidents_2005_to_2007.csv')
# Out:
# C:\Users\GADKARI\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data = data.drop('Junction_Detail', 1)

# %%
data.corr()
# Out:
#                             Location_Easting_OSGR  Location_Northing_OSGR  \
# Location_Easting_OSGR                    1.000000               -0.400071
# Location_Northing_OSGR                  -0.400071                1.000000
# Longitude                                0.999340               -0.412000
# Latitude                                -0.401897                0.999973
# Police_Force                            -0.354738                0.159744
# Accident_Severity                       -0.002330               -0.031357
# Number_of_Vehicles                       0.024541               -0.047347
# Number_of_Casualties                    -0.035489                0.032982
# Day_of_Week                             -0.004410                0.003740
# Local_Authority_(District)              -0.378700                0.107653
# 1st_Road_Class                          -0.057017                0.022690
# 1st_Road_Number                         -0.081045                0.038943
# Speed_limit                             -0.061354                0.020464
# 2nd_Road_Class                           0.029378               -0.009487
# 2nd_Road_Number                          0.016641               -0.001457
# Urban_or_Rural_Area                     -0.080688                0.037441
# Year                                    -0.001840               -0.000792
#
#                             Longitude  Latitude  Police_Force  \
# Location_Easting_OSGR        0.999340 -0.401897     -0.354738
# Location_Northing_OSGR      -0.412000  0.999973      0.159744
# Longitude                    1.000000 -0.413726     -0.368679
# Latitude                    -0.413726  1.000000      0.157508
# Police_Force                -0.368679  0.157508      1.000000
# Accident_Severity           -0.001517 -0.031227     -0.021871
# Number_of_Vehicles           0.025990 -0.047108     -0.024201
# Number_of_Casualties        -0.034358  0.033130      0.003357
# Day_of_Week                 -0.004385  0.003734      0.001934
# Local_Authority_(District)  -0.389354  0.105757      0.981736
# 1st_Road_Class              -0.055553  0.022696      0.035413
# 1st_Road_Number             -0.078798  0.039870     -0.004791
# Speed_limit                 -0.059824  0.020119      0.192082
# 2nd_Road_Class               0.030157 -0.009133     -0.112062
# 2nd_Road_Number              0.017810 -0.000915     -0.017549
# Urban_or_Rural_Area         -0.079076  0.036901      0.232472
# Year                        -0.001814 -0.000796      0.007567
#
#                             Accident_Severity  Number_of_Vehicles  \
# Location_Easting_OSGR               -0.002330            0.024541
# Location_Northing_OSGR              -0.031357           -0.047347
# Longitude                           -0.001517            0.025990
# Latitude                            -0.031227           -0.047108
# Police_Force                        -0.021871           -0.024201
# Accident_Severity                    1.000000            0.073370
# Number_of_Vehicles                   0.073370            1.000000
# Number_of_Casualties                -0.110936            0.222985
# Day_of_Week                          0.002000           -0.003963
# Local_Authority_(District)          -0.019350           -0.018856
# 1st_Road_Class                       0.021280           -0.142221
# 1st_Road_Number                      0.000060           -0.007516
# Speed_limit                         -0.081672            0.085952
# 2nd_Road_Class                       0.068744            0.067805
# 2nd_Road_Number                      0.030478            0.025885
# Urban_or_Rural_Area                 -0.082840            0.042068
# Year                                -0.008257           -0.002009
#
#                             Number_of_Casualties  Day_of_Week  \
# Location_Easting_OSGR                  -0.035489    -0.004410
# Location_Northing_OSGR                  0.032982     0.003740
# Longitude                              -0.034358    -0.004385
# Latitude                                0.033130     0.003734
# Police_Force                            0.003357     0.001934
# Accident_Severity                      -0.110936     0.002000
# Number_of_Vehicles                      0.222985    -0.003963
# Number_of_Casualties                    1.000000    -0.004802
# Day_of_Week                            -0.004802     1.000000
# Local_Authority_(District)              0.009684     0.002119
# 1st_Road_Class                         -0.084650     0.009993
# 1st_Road_Number                         0.010787     0.002174
# Speed_limit                             0.139938    -0.016105
# 2nd_Road_Class                         -0.029593     0.005604
# 2nd_Road_Number                         0.000879     0.001723
# Urban_or_Rural_Area                     0.120434    -0.015590
# Year                                   -0.001501    -0.004568
#
#                             Local_Authority_(District)  1st_Road_Class  \
# Location_Easting_OSGR                        -0.378700       -0.057017
# Location_Northing_OSGR                        0.107653        0.022690
# Longitude                                    -0.389354       -0.055553
# Latitude                                      0.105757        0.022696
# Police_Force                                  0.981736        0.035413
# Accident_Severity                            -0.019350        0.021280
# Number_of_Vehicles                           -0.018856       -0.142221
# Number_of_Casualties                          0.009684       -0.084650
# Day_of_Week                                   0.002119        0.009993
# Local_Authority_(District)                    1.000000        0.046797
# 1st_Road_Class                                0.046797        1.000000
# 1st_Road_Number                               0.005044       -0.097588
# Speed_limit                                   0.198773       -0.398476
# 2nd_Road_Class                               -0.109727        0.115269
# 2nd_Road_Number                              -0.017031       -0.033613
# Urban_or_Rural_Area                           0.243234       -0.240545
# Year                                          0.008495       -0.003975
#
#                             1st_Road_Number  Speed_limit  2nd_Road_Class  \
# Location_Easting_OSGR             -0.081045    -0.061354        0.029378
# Location_Northing_OSGR             0.038943     0.020464       -0.009487
# Longitude                         -0.078798    -0.059824        0.030157
# Latitude                           0.039870     0.020119       -0.009133
# Police_Force                      -0.004791     0.192082       -0.112062
# Accident_Severity                  0.000060    -0.081672        0.068744
# Number_of_Vehicles                -0.007516     0.085952        0.067805
# Number_of_Casualties               0.010787     0.139938       -0.029593
# Day_of_Week                        0.002174    -0.016105        0.005604
# Local_Authority_(District)         0.005044     0.198773       -0.109727
# 1st_Road_Class                    -0.097588    -0.398476        0.115269
# 1st_Road_Number                    1.000000    -0.064232        0.039308
# Speed_limit                       -0.064232     1.000000       -0.332436
# 2nd_Road_Class                     0.039308    -0.332436        1.000000
# 2nd_Road_Number                    0.183027    -0.057357        0.164272
# Urban_or_Rural_Area               -0.014916     0.687871       -0.292920
# Year                               0.003601    -0.000046       -0.002065
#
#                             2nd_Road_Number  Urban_or_Rural_Area      Year
# Location_Easting_OSGR              0.016641            -0.080688 -0.001840
# Location_Northing_OSGR            -0.001457             0.037441 -0.000792
# Longitude                          0.017810            -0.079076 -0.001814
# Latitude                          -0.000915             0.036901 -0.000796
# Police_Force                      -0.017549             0.232472  0.007567
# Accident_Severity                  0.030478            -0.082840 -0.008257
# Number_of_Vehicles                 0.025885             0.042068 -0.002009
# Number_of_Casualties               0.000879             0.120434 -0.001501
# Day_of_Week                        0.001723            -0.015590 -0.004568
# Local_Authority_(District)        -0.017031             0.243234  0.008495
# 1st_Road_Class                    -0.033613            -0.240545 -0.003975
# 1st_Road_Number                    0.183027            -0.014916  0.003601
# Speed_limit                       -0.057357             0.687871 -0.000046
# 2nd_Road_Class                     0.164272            -0.292920 -0.002065
# 2nd_Road_Number                    1.000000            -0.045469 -0.000528
# Urban_or_Rural_Area               -0.045469             1.000000  0.005545
# Year                              -0.000528             0.005545  1.000000

# %%
road_type=np.array(data['Road_Type'])

# %%
road_type = set(road_type)
print(road_type)
mapping = {'Dual carriageway': 1, 'One way street': 2, 'Roundabout': 3, 'Single carriageway': 4, 'Slip road': 5, 'Unknown': 6}

data=data.replace({'Road_Type': mapping})
# Out:
# {'Roundabout', 'Dual carriageway', 'One way street', 'Slip road', 'Unknown', 'Single carriageway'}

# %%
data.fillna(0, inplace=True)

# %%
data
# Out:
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0       200501BS00001               525680.0                178240.0
# 1       200501BS00002               524170.0                181650.0
# 2       200501BS00003               524520.0                182240.0
# 3       200501BS00004               526900.0                177530.0
# 4       200501BS00005               528060.0                179040.0
# 5       200501BS00006               524770.0                181160.0
# 6       200501BS00007               524220.0                180830.0
# 7       200501BS00009               525890.0                179710.0
# 8       200501BS00010               527350.0                177650.0
# 9       200501BS00011               524550.0                180810.0
# 10      200501BS00012               526240.0                178900.0
# 11      200501BS00014               526170.0                177690.0
# 12      200501BS00015               525590.0                178520.0
# 13      200501BS00016               527990.0                178690.0
# 14      200501BS00017               526700.0                178970.0
# 15      200501BS00018               526460.0                177460.0
# 16      200501BS00019               524680.0                179450.0
# 17      200501BS00020               527000.0                179020.0
# 18      200501BS00021               527810.0                178010.0
# 19      200501BS00022               526790.0                178980.0
# 20      200501BS00023               525940.0                178680.0
# 21      200501BS00024               524700.0                180880.0
# 22      200501BS00025               526930.0                177490.0
# 23      200501BS00028               527290.0                178710.0
# 24      200501BS00029               527380.0                179280.0
# 25      200501BS00031               523930.0                180330.0
# 26      200501BS00032               524470.0                180980.0
# 27      200501BS00033               525570.0                178190.0
# 28      200501BS70001               526240.0                178900.0
# 29      200501BS70002               527780.0                179160.0
# ...               ...                    ...                     ...
# 569981       2.01E+12               330640.0                567430.0
# 569982       2.01E+12               305280.0                606420.0
# 569983       2.01E+12               319490.0                566720.0
# 569984       2.01E+12               330730.0                572920.0
# 569985       2.01E+12               308390.0                581590.0
# 569986       2.01E+12               337420.0                576320.0
# 569987       2.01E+12               325070.0                582420.0
# 569988       2.01E+12               330660.0                581430.0
# 569989       2.01E+12               305500.0                591230.0
# 569990       2.01E+12               313600.0                581800.0
# 569991       2.01E+12               310550.0                588650.0
# 569992       2.01E+12               319310.0                566850.0
# 569993       2.01E+12               310190.0                591800.0
# 569994       2.01E+12               324330.0                570140.0
# 569995       2.01E+12               308850.0                578930.0
# 569996       2.01E+12               310430.0                580790.0
# 569997       2.01E+12               315720.0                569080.0
# 569998       2.01E+12               327730.0                567080.0
# 569999       2.01E+12               308280.0                582390.0
# 570000       2.01E+12               328300.0                566530.0
# 570001       2.01E+12               326790.0                571080.0
# 570002       2.01E+12               311820.0                580750.0
# 570003       2.01E+12               316030.0                577390.0
# 570004       2.01E+12               315930.0                577790.0
# 570005       2.01E+12               317900.0                567550.0
# 570006       2.01E+12               322650.0                566300.0
# 570007       2.01E+12               323710.0                566150.0
# 570008       2.01E+12               336900.0                586230.0
# 570009       2.01E+12               332390.0                567240.0
# 570010       2.01E+12               314040.0                579740.0
#
#         Longitude   Latitude  Police_Force  Accident_Severity  \
# 0       -0.191170  51.489096             1                  2
# 1       -0.211708  51.520075             1                  3
# 2       -0.206458  51.525301             1                  3
# 3       -0.173862  51.482442             1                  3
# 4       -0.156618  51.495752             1                  3
# 5       -0.203238  51.515540             1                  3
# 6       -0.211277  51.512695             1                  3
# 7       -0.187623  51.502260             1                  3
# 8       -0.167342  51.483420             1                  3
# 9       -0.206531  51.512443             1                  3
# 10      -0.182872  51.494902             1                  3
# 11      -0.184312  51.484044             1                  3
# 12      -0.192366  51.491632             1                  3
# 13      -0.157753  51.492622             1                  3
# 14      -0.176224  51.495429             1                  3
# 15      -0.180220  51.481912             1                  3
# 16      -0.205139  51.500191             1                  2
# 17      -0.171887  51.495811             1                  3
# 18      -0.160590  51.486552             1                  3
# 19      -0.174925  51.495498             1                  2
# 20      -0.187270  51.492992             1                  3
# 21      -0.204346  51.513039             1                  3
# 22      -0.173445  51.482076             1                  3
# 23      -0.167824  51.492960             1                  3
# 24      -0.166322  51.498062             1                  3
# 25      -0.215629  51.508265             1                  3
# 26      -0.207623  51.513988             1                  3
# 27      -0.192771  51.488671             1                  3
# 28      -0.182872  51.494902             1                  3
# 29      -0.160606  51.496893             1                  3
# ...           ...        ...           ...                ...
# 569981  -3.085733  54.996620            98                  3
# 569982  -3.495072  55.342687            98                  2
# 569983  -3.259781  54.988561            98                  3
# 569984  -3.085659  55.045958            98                  3
# 569985  -3.437981  55.120225            98                  3
# 569986  -2.981720  55.077396            98                  3
# 569987  -3.176726  55.130487            98                  3
# 569988  -3.088829  55.122407            98                  3
# 569989  -3.486498  55.206279            98                  3
# 569990  -3.356378  55.123048            98                  3
# 569991  -3.406353  55.184043            98                  3
# 569992  -3.262630  54.989700            98                  2
# 569993  -3.413007  55.212275            98                  3
# 569994  -3.185063  55.020047            98                  3
# 569995  -3.429917  55.096414            98                  3
# 569996  -3.405752  55.113411            98                  3
# 569997  -3.319379  55.009139            98                  3
# 569998  -3.131122  54.993061            98                  3
# 569999  -3.439964  55.127391            98                  2
# 570000  -3.122077  54.988202            98                  3
# 570001  -3.146837  55.028861            98                  3
# 570002  -3.383955  55.113302            98                  2
# 570003  -3.316981  55.083848            98                  3
# 570004  -3.318665  55.087424            98                  1
# 570005  -3.284862  54.995758            98                  3
# 570006  -3.210294  54.985289            98                  3
# 570007  -3.193693  54.984105            98                  2
# 570008  -2.992068  55.166369            98                  3
# 570009  -3.058338  54.995154            98                  3
# 570010  -3.348857  55.104618            98                  2
#
#         Number_of_Vehicles  Number_of_Casualties        Date  ...   \
# 0                        1                     1  04/01/2005  ...
# 1                        1                     1  05/01/2005  ...
# 2                        2                     1  06/01/2005  ...
# 3                        1                     1  07/01/2005  ...
# 4                        1                     1  10/01/2005  ...
# 5                        2                     1  11/01/2005  ...
# 6                        2                     1  13/01/2005  ...
# 7                        1                     2  14/01/2005  ...
# 8                        2                     2  15/01/2005  ...
# 9                        2                     5  15/01/2005  ...
# 10                       1                     1  16/01/2005  ...
# 11                       2                     1  25/01/2005  ...
# 12                       1                     1  11/01/2005  ...
# 13                       2                     1  18/01/2005  ...
# 14                       1                     2  18/01/2005  ...
# 15                       1                     1  18/01/2005  ...
# 16                       2                     1  20/01/2005  ...
# 17                       2                     1  21/01/2005  ...
# 18                       2                     1  21/01/2005  ...
# 19                       1                     1  08/01/2005  ...
# 20                       1                     1  24/01/2005  ...
# 21                       2                     1  24/01/2005  ...
# 22                       2                     1  24/01/2005  ...
# 23                       2                     1  18/01/2005  ...
# 24                       2                     1  29/01/2005  ...
# 25                       1                     1  19/01/2005  ...
# 26                       2                     1  30/01/2005  ...
# 27                       2                     2  29/01/2005  ...
# 28                       2                     1  01/02/2005  ...
# 29                       2                     1  02/02/2005  ...
# ...                    ...                   ...         ...  ...
# 569981                   2                     1  29/10/2007  ...
# 569982                   2                     1  30/10/2007  ...
# 569983                   1                     1  02/11/2007  ...
# 569984                   1                     1  04/11/2007  ...
# 569985                   2                     1  13/11/2007  ...
# 569986                   2                     1  13/11/2007  ...
# 569987                   1                     1  13/11/2007  ...
# 569988                   1                     1  15/11/2007  ...
# 569989                   1                     1  17/11/2007  ...
# 569990                   2                     1  18/11/2007  ...
# 569991                   1                     1  20/11/2007  ...
# 569992                   1                     1  20/11/2007  ...
# 569993                   2                     1  07/11/2007  ...
# 569994                   1                     1  27/11/2007  ...
# 569995                   2                     1  29/11/2007  ...
# 569996                   2                     1  30/11/2007  ...
# 569997                   1                     1  02/12/2007  ...
# 569998                   1                     1  03/12/2007  ...
# 569999                   2                     1  06/12/2007  ...
# 570000                   1                     1  07/12/2007  ...
# 570001                   1                     1  14/12/2007  ...
# 570002                   1                     1  16/12/2007  ...
# 570003                   2                     1  17/12/2007  ...
# 570004                   2                     1  17/12/2007  ...
# 570005                   2                     2  19/12/2007  ...
# 570006                   1                     1  20/12/2007  ...
# 570007                   1                     2  21/12/2007  ...
# 570008                   1                     1  23/12/2007  ...
# 570009                   1                     1  23/12/2007  ...
# 570010                   2                     2  22/12/2007  ...
#
#             Pedestrian_Crossing-Physical_Facilities  \
# 0                                    Zebra crossing
# 1       Pedestrian phase at traffic signal junction
# 2             No physical crossing within 50 meters
# 3             No physical crossing within 50 meters
# 4             No physical crossing within 50 meters
# 5             No physical crossing within 50 meters
# 6             No physical crossing within 50 meters
# 7             No physical crossing within 50 meters
# 8       Pedestrian phase at traffic signal junction
# 9                                    Central refuge
# 10      Pedestrian phase at traffic signal junction
# 11      Pedestrian phase at traffic signal junction
# 12                                   Zebra crossing
# 13            No physical crossing within 50 meters
# 14            No physical crossing within 50 meters
# 15                                   Zebra crossing
# 16            No physical crossing within 50 meters
# 17            No physical crossing within 50 meters
# 18            No physical crossing within 50 meters
# 19            No physical crossing within 50 meters
# 20            No physical crossing within 50 meters
# 21            No physical crossing within 50 meters
# 22            No physical crossing within 50 meters
# 23            No physical crossing within 50 meters
# 24      Pedestrian phase at traffic signal junction
# 25                                   Zebra crossing
# 26            No physical crossing within 50 meters
# 27      Pedestrian phase at traffic signal junction
# 28      Pedestrian phase at traffic signal junction
# 29                                   Zebra crossing
# ...                                             ...
# 569981        No physical crossing within 50 meters
# 569982        No physical crossing within 50 meters
# 569983        No physical crossing within 50 meters
# 569984        No physical crossing within 50 meters
# 569985        No physical crossing within 50 meters
# 569986        No physical crossing within 50 meters
# 569987        No physical crossing within 50 meters
# 569988        No physical crossing within 50 meters
# 569989        No physical crossing within 50 meters
# 569990        No physical crossing within 50 meters
# 569991        No physical crossing within 50 meters
# 569992        No physical crossing within 50 meters
# 569993        No physical crossing within 50 meters
# 569994        No physical crossing within 50 meters
# 569995        No physical crossing within 50 meters
# 569996        No physical crossing within 50 meters
# 569997        No physical crossing within 50 meters
# 569998        No physical crossing within 50 meters
# 569999        No physical crossing within 50 meters
# 570000        No physical crossing within 50 meters
# 570001        No physical crossing within 50 meters
# 570002        No physical crossing within 50 meters
# 570003        No physical crossing within 50 meters
# 570004        No physical crossing within 50 meters
# 570005        No physical crossing within 50 meters
# 570006        No physical crossing within 50 meters
# 570007        No physical crossing within 50 meters
# 570008        No physical crossing within 50 meters
# 570009        No physical crossing within 50 meters
# 570010        No physical crossing within 50 meters
#
#                                Light_Conditions          Weather_Conditions  \
# 0                Daylight: Street light present  Raining without high winds
# 1       Darkness: Street lights present and lit     Fine without high winds
# 2       Darkness: Street lights present and lit     Fine without high winds
# 3                Daylight: Street light present     Fine without high winds
# 4             Darkness: Street lighting unknown     Fine without high winds
# 5                Daylight: Street light present  Raining without high winds
# 6       Darkness: Street lights present and lit     Fine without high winds
# 7                Daylight: Street light present     Fine without high winds
# 8       Darkness: Street lights present and lit     Fine without high winds
# 9                Daylight: Street light present     Fine without high winds
# 10      Darkness: Street lights present and lit     Fine without high winds
# 11      Darkness: Street lights present and lit     Fine without high winds
# 12               Daylight: Street light present  Raining without high winds
# 13      Darkness: Street lights present and lit  Raining without high winds
# 14               Daylight: Street light present     Fine without high winds
# 15               Daylight: Street light present     Fine without high winds
# 16      Darkness: Street lights present and lit     Fine without high winds
# 17               Daylight: Street light present     Fine without high winds
# 18      Darkness: Street lights present and lit     Fine without high winds
# 19      Darkness: Street lights present and lit     Fine without high winds
# 20      Darkness: Street lights present and lit     Fine without high winds
# 21      Darkness: Street lights present and lit     Fine without high winds
# 22      Darkness: Street lights present and lit     Fine without high winds
# 23      Darkness: Street lights present and lit     Fine without high winds
# 24               Daylight: Street light present     Fine without high winds
# 25      Darkness: Street lights present and lit  Raining without high winds
# 26      Darkness: Street lights present and lit     Fine without high winds
# 27               Daylight: Street light present  Raining without high winds
# 28      Darkness: Street lights present and lit  Raining without high winds
# 29      Darkness: Street lights present and lit     Fine without high winds
# ...                                         ...                         ...
# 569981           Daylight: Street light present     Fine without high winds
# 569982            Darkeness: No street lighting     Fine without high winds
# 569983           Daylight: Street light present     Fine without high winds
# 569984           Daylight: Street light present  Raining without high winds
# 569985           Daylight: Street light present     Fine without high winds
# 569986           Daylight: Street light present  Raining without high winds
# 569987            Darkeness: No street lighting     Fine without high winds
# 569988            Darkeness: No street lighting     Fine without high winds
# 569989            Darkeness: No street lighting  Raining without high winds
# 569990  Darkness: Street lights present and lit     Fine without high winds
# 569991            Darkeness: No street lighting  Raining without high winds
# 569992  Darkness: Street lights present and lit  Raining without high winds
# 569993            Darkeness: No street lighting     Fine without high winds
# 569994            Darkeness: No street lighting  Raining without high winds
# 569995           Daylight: Street light present     Fine without high winds
# 569996           Daylight: Street light present     Fine without high winds
# 569997           Daylight: Street light present     Fine without high winds
# 569998           Daylight: Street light present     Fine without high winds
# 569999  Darkness: Street lights present and lit  Raining without high winds
# 570000            Darkeness: No street lighting     Fine without high winds
# 570001           Daylight: Street light present     Fine without high winds
# 570002            Darkeness: No street lighting     Fine without high winds
# 570003           Daylight: Street light present     Fine without high winds
# 570004           Daylight: Street light present     Fine without high winds
# 570005  Darkness: Street lights present and lit     Fine without high winds
# 570006            Darkeness: No street lighting                       Other
# 570007           Daylight: Street light present                       Other
# 570008            Darkeness: No street lighting                 Fog or mist
# 570009  Darkness: Street lights present and lit     Fine without high winds
# 570010           Daylight: Street light present  Raining without high winds
#
#        Road_Surface_Conditions  Special_Conditions_at_Site  \
# 0                     Wet/Damp                        None
# 1                          Dry                        None
# 2                          Dry                        None
# 3                          Dry                        None
# 4                     Wet/Damp                        None
# 5                     Wet/Damp                Ol or diesel
# 6                          Dry                        None
# 7                          Dry                        None
# 8                          Dry                        None
# 9                          Dry                        None
# 10                         Dry                        None
# 11                    Wet/Damp                        None
# 12                    Wet/Damp                        None
# 13                    Wet/Damp                        None
# 14                         Dry                        None
# 15                         Dry                        None
# 16                         Dry                        None
# 17                         Dry                        None
# 18                         Dry                        None
# 19                         Dry                        None
# 20                         Dry                        None
# 21                         Dry                        None
# 22                   Frost/Ice                        None
# 23                         Dry                        None
# 24                    Wet/Damp                        None
# 25                    Wet/Damp                        None
# 26                         Dry                        None
# 27                    Wet/Damp                        None
# 28                    Wet/Damp                        None
# 29                         Dry                        None
# ...                        ...                         ...
# 569981                     Dry                   Roadworks
# 569982                Wet/Damp                        None
# 569983                     Dry                        None
# 569984                Wet/Damp                Ol or diesel
# 569985                Wet/Damp                Ol or diesel
# 569986                Wet/Damp                        None
# 569987                     Dry                        None
# 569988                     Dry                        None
# 569989                Wet/Damp                        None
# 569990                Wet/Damp                        None
# 569991                Wet/Damp                        None
# 569992                Wet/Damp                        None
# 569993                     Dry                        None
# 569994                Wet/Damp                        None
# 569995                     Dry                        None
# 569996                Wet/Damp                        None
# 569997                Wet/Damp                        None
# 569998               Frost/Ice                        None
# 569999                Wet/Damp                        None
# 570000                Wet/Damp                        None
# 570001                     Dry                        None
# 570002               Frost/Ice                        None
# 570003                Wet/Damp                        None
# 570004                     Dry                        None
# 570005                     Dry                        None
# 570006               Frost/Ice                        None
# 570007               Frost/Ice                        None
# 570008               Frost/Ice                        None
# 570009                Wet/Damp                        None
# 570010               Frost/Ice                        None
#
#                        Carriageway_Hazards  Urban_or_Rural_Area  \
# 0                                     None                    1
# 1                                     None                    1
# 2                                     None                    1
# 3                                     None                    1
# 4                                     None                    1
# 5                                     None                    1
# 6                                     None                    1
# 7                                     None                    1
# 8                                     None                    1
# 9                                     None                    1
# 10                                    None                    1
# 11                                    None                    1
# 12                                    None                    1
# 13                                    None                    1
# 14                                    None                    1
# 15                                    None                    1
# 16                                    None                    1
# 17                                    None                    1
# 18                                    None                    1
# 19                                    None                    1
# 20                                    None                    1
# 21                                    None                    1
# 22                                    None                    1
# 23                                    None                    1
# 24                                    None                    1
# 25                                    None                    1
# 26                                    None                    1
# 27                                    None                    1
# 28                                    None                    1
# 29                                    None                    1
# ...                                    ...                  ...
# 569981                                None                    2
# 569982                                None                    2
# 569983                                None                    2
# 569984                                None                    2
# 569985                                None                    2
# 569986                                None                    2
# 569987                                None                    2
# 569988                                None                    2
# 569989                                None                    2
# 569990                                None                    2
# 569991                                None                    2
# 569992                                None                    2
# 569993                                None                    2
# 569994                                None                    2
# 569995                                None                    2
# 569996                                None                    2
# 569997                                None                    2
# 569998                                None                    2
# 569999                                None                    2
# 570000                                None                    2
# 570001                                None                    2
# 570002                                None                    2
# 570003         Other object in carriageway                    2
# 570004  Involvement with previous accident                    2
# 570005                                None                    2
# 570006                                None                    2
# 570007                                None                    2
# 570008                                None                    2
# 570009                                None                    2
# 570010                                None                    2
#
#         Did_Police_Officer_Attend_Scene_of_Accident LSOA_of_Accident_Location  \
# 0                                               Yes                 E01002849
# 1                                               Yes                 E01002909
# 2                                               Yes                 E01002857
# 3                                               Yes                 E01002840
# 4                                               Yes                 E01002863
# 5                                               Yes                 E01002832
# 6                                               Yes                 E01002875
# 7                                               Yes                 E01002889
# 8                                               Yes                 E01002900
# 9                                               Yes                 E01002875
# 10                                              Yes                 E01002835
# 11                                              Yes                 E01002912
# 12                                              Yes                 E01002849
# 13                                              Yes                 E01002902
# 14                                              Yes                 E01002821
# 15                                              Yes                 E01002840
# 16                                              Yes                 E01002864
# 17                                              Yes                 E01002821
# 18                                              Yes                 E01002901
# 19                                              Yes                 E01002821
# 20                                               No                 E01002839
# 21                                               No                 E01002882
# 22                                              Yes                 E01002840
# 23                                               No                 E01002858
# 24                                              Yes                 E01002819
# 25                                              Yes                 E01001944
# 26                                              Yes                 E01002874
# 27                                                0                 E01002849
# 28                                              Yes                 E01002835
# 29                                              Yes                 E01002863
# ...                                             ...                       ...
# 569981                                          Yes                         0
# 569982                                          Yes                         0
# 569983                                          Yes                         0
# 569984                                          Yes                         0
# 569985                                          Yes                         0
# 569986                                          Yes                         0
# 569987                                          Yes                         0
# 569988                                          Yes                         0
# 569989                                          Yes                         0
# 569990                                          Yes                         0
# 569991                                          Yes                         0
# 569992                                          Yes                         0
# 569993                                          Yes                         0
# 569994                                          Yes                         0
# 569995                                          Yes                         0
# 569996                                          Yes                         0
# 569997                                          Yes                         0
# 569998                                          Yes                         0
# 569999                                          Yes                         0
# 570000                                          Yes                         0
# 570001                                          Yes                         0
# 570002                                          Yes                         0
# 570003                                          Yes                         0
# 570004                                          Yes                         0
# 570005                                          Yes                         0
# 570006                                          Yes                         0
# 570007                                          Yes                         0
# 570008                                          Yes                         0
# 570009                                           No                         0
# 570010                                          Yes                         0
#
#         Year
# 0       2005
# 1       2005
# 2       2005
# 3       2005
# 4       2005
# 5       2005
# 6       2005
# 7       2005
# 8       2005
# 9       2005
# 10      2005
# 11      2005
# 12      2005
# 13      2005
# 14      2005
# 15      2005
# 16      2005
# 17      2005
# 18      2005
# 19      2005
# 20      2005
# 21      2005
# 22      2005
# 23      2005
# 24      2005
# 25      2005
# 26      2005
# 27      2005
# 28      2005
# 29      2005
# ...      ...
# 569981  2007
# 569982  2007
# 569983  2007
# 569984  2007
# 569985  2007
# 569986  2007
# 569987  2007
# 569988  2007
# 569989  2007
# 569990  2007
# 569991  2007
# 569992  2007
# 569993  2007
# 569994  2007
# 569995  2007
# 569996  2007
# 569997  2007
# 569998  2007
# 569999  2007
# 570000  2007
# 570001  2007
# 570002  2007
# 570003  2007
# 570004  2007
# 570005  2007
# 570006  2007
# 570007  2007
# 570008  2007
# 570009  2007
# 570010  2007
#
# [570011 rows x 32 columns]

# %%
junction_control=np.array(data['Junction_Control'])
junction_control = set(junction_control)
print(junction_control)
# Out:
# {0, 'Automatic traffic signal', 'Authorised person', 'Stop Sign', 'Giveway or uncontrolled'}

# %%
mapping1 = {'Automatic traffic signal': 1, 'Giveway or uncontrolled': 2, 'Authorised person': 3, 'Stop Sign': 4}

data=data.replace({'Junction_Control': mapping1})

# %%
pedestrian_crossing_human_control=np.array(data['Pedestrian_Crossing-Human_Control'])
pedestrian_crossing_human_control = set(pedestrian_crossing_human_control)
print(pedestrian_crossing_human_control)
# Out:
# {'Control by other authorised person', 0, 'None within 50 metres', 'Control by school crossing patrol'}

# %%
mapping2 = {'Control by school crossing patrol': 1, 'Control by other authorised person': 2, 'None within 50 metres': 3}

data=data.replace({'Pedestrian_Crossing-Human_Control': mapping2})

# %%
pedestrian_crossing_physical_facilities=np.array(data['Pedestrian_Crossing-Physical_Facilities'])
pedestrian_crossing_physical_facilities = set(pedestrian_crossing_physical_facilities)
print(pedestrian_crossing_physical_facilities)
# Out:
# {0, 'Zebra crossing', 'Footbridge or subway', 'No physical crossing within 50 meters', 'Pedestrian phase at traffic signal junction', 'non-junction pedestrian crossing', 'Central refuge'}

# %%
mapping3 = {'No physical crossing within 50 meters': 1, 'Central refuge': 2, 'Zebra crossing': 3, 'Footbridge or subway': 4, 'non-junction pedestrian crossing': 5, 'Pedestrian phase at traffic signal junction': 6}

data=data.replace({'Pedestrian_Crossing-Physical_Facilities': mapping3})

# %%
light_conditions=np.array(data['Light_Conditions'])
light_conditions = set(light_conditions)
print(light_conditions)
# Out:
# {'Darkness: Street lights present and lit', 'Darkness: Street lighting unknown', 'Daylight: Street light present', 'Darkeness: No street lighting', 'Darkness: Street lights present but unlit'}

# %%
mapping4 = {'Daylight: Street light present': 1, 'Darkness: Street lighting unknown': 2, 'Darkeness: No street lighting': 3, 'Darkness: Street lights present and lit': 4, 'Darkness: Street lights present but unlit': 5}

data=data.replace({'Light_Conditions': mapping4})

# %%
weather_conditions=np.array(data['Weather_Conditions'])
weather_conditions = set(weather_conditions)
print(weather_conditions)
# Out:
# {0, 'Raining with high winds', 'Fine with high winds', 'Other', 'Snowing without high winds', 'Fine without high winds', 'Fog or mist', 'Unknown', 'Snowing with high winds', 'Raining without high winds'}

# %%
mapping5 = {'Snowing without high winds': 1, 'Raining without high winds': 2, 'Fine without high winds': 3, 'Fog or mist': 4, 'Raining with high winds': 5, 'Fine with high winds': 6, 'Snowing with high winds': 7, 'Other': 8, 'Unknown':9}

data=data.replace({'Weather_Conditions': mapping5})

# %%
road_surface_conditions=np.array(data['Road_Surface_Conditions'])
road_surface_conditions = set(road_surface_conditions)
print(road_surface_conditions)
# Out:
# {'Wet/Damp', 0, 'Frost/Ice', 'Snow', 'Flood (Over 3cm of water)', 'Dry'}

# %%
mapping6 = {'Wet/Damp': 1, 'Flood (Over 3cm of water)': 2, 'Dry': 3, 'Snow': 4, 'Frost/Ice': 5}

data=data.replace({'Road_Surface_Conditions': mapping6})

# %%
data=data.drop('Special_Conditions_at_Site', 1)
data=data.drop('Carriageway_Hazards', 1)
data=data.drop('Did_Police_Officer_Attend_Scene_of_Accident', 1)
data=data.drop('LSOA_of_Accident_Location', 1)
data=data.drop('Local_Authority_(District)', 1)
data=data.drop('Location_Easting_OSGR', 1)
data=data.drop('Location_Northing_OSGR', 1)

# %%
corltn=data.corr()
plt.figure(figsize=(12, 10))
plt.imshow(corltn, cmap='RdYlGn', interpolation='none', aspect='auto')
plt.colorbar()
plt.xticks(range(len(corltn)), corltn.columns, rotation='vertical')
plt.yticks(range(len(corltn)), corltn.columns);
plt.suptitle(' Correlations Heat Map for attributes', fontsize=16, fontweight='bold')
plt.show()

# %%
data.corr()
# Out:
#                                          Longitude  Latitude  Police_Force  \
# Longitude                                 1.000000 -0.378799     -0.368377
# Latitude                                 -0.378799  1.000000      0.136687
# Police_Force                             -0.368377  0.136687      1.000000
# Accident_Severity                        -0.001515 -0.028156     -0.021871
# Number_of_Vehicles                        0.025970 -0.041964     -0.024201
# Number_of_Casualties                     -0.034360  0.030100      0.003357
# Day_of_Week                              -0.004371  0.002965      0.001934
# 1st_Road_Class                           -0.055530  0.020079      0.035413
# 1st_Road_Number                          -0.078792  0.036216     -0.004791
# Road_Type                                -0.009731  0.002674     -0.005843
# Speed_limit                              -0.059723  0.015427      0.192082
# Junction_Control                          0.047362 -0.010469     -0.099266
# 2nd_Road_Class                            0.030071 -0.005766     -0.112062
# 2nd_Road_Number                           0.017780  0.000009     -0.017549
# Pedestrian_Crossing-Human_Control         0.026105 -0.031831     -0.031681
# Pedestrian_Crossing-Physical_Facilities   0.045955  0.006558     -0.077739
# Light_Conditions                          0.021086  0.009720     -0.023567
# Weather_Conditions                       -0.006493 -0.016755      0.027885
# Road_Surface_Conditions                   0.071014 -0.047321     -0.055041
# Urban_or_Rural_Area                      -0.078369  0.014127      0.232472
# Year                                     -0.001930  0.002860      0.007567
#
#                                          Accident_Severity  \
# Longitude                                        -0.001515
# Latitude                                         -0.028156
# Police_Force                                     -0.021871
# Accident_Severity                                 1.000000
# Number_of_Vehicles                                0.073370
# Number_of_Casualties                             -0.110936
# Day_of_Week                                       0.002000
# 1st_Road_Class                                    0.021280
# 1st_Road_Number                                   0.000060
# Road_Type                                        -0.013443
# Speed_limit                                      -0.081672
# Junction_Control                                  0.071285
# 2nd_Road_Class                                    0.068744
# 2nd_Road_Number                                   0.030478
# Pedestrian_Crossing-Human_Control                -0.009381
# Pedestrian_Crossing-Physical_Facilities           0.013191
# Light_Conditions                                 -0.055661
# Weather_Conditions                                0.013345
# Road_Surface_Conditions                          -0.002434
# Urban_or_Rural_Area                              -0.082840
# Year                                             -0.008257
#
#                                          Number_of_Vehicles  \
# Longitude                                          0.025970
# Latitude                                          -0.041964
# Police_Force                                      -0.024201
# Accident_Severity                                  0.073370
# Number_of_Vehicles                                 1.000000
# Number_of_Casualties                               0.222985
# Day_of_Week                                       -0.003963
# 1st_Road_Class                                    -0.142221
# 1st_Road_Number                                   -0.007516
# Road_Type                                         -0.097474
# Speed_limit                                        0.085952
# Junction_Control                                   0.075496
# 2nd_Road_Class                                     0.067805
# 2nd_Road_Number                                    0.025885
# Pedestrian_Crossing-Human_Control                  0.021641
# Pedestrian_Crossing-Physical_Facilities           -0.053470
# Light_Conditions                                  -0.070242
# Weather_Conditions                                -0.013091
# Road_Surface_Conditions                           -0.010377
# Urban_or_Rural_Area                                0.042068
# Year                                              -0.002009
#
#                                          Number_of_Casualties  Day_of_Week  \
# Longitude                                           -0.034360    -0.004371
# Latitude                                             0.030100     0.002965
# Police_Force                                         0.003357     0.001934
# Accident_Severity                                   -0.110936     0.002000
# Number_of_Vehicles                                   0.222985    -0.003963
# Number_of_Casualties                                 1.000000    -0.004802
# Day_of_Week                                         -0.004802     1.000000
# 1st_Road_Class                                      -0.084650     0.009993
# 1st_Road_Number                                      0.010787     0.002174
# Road_Type                                           -0.044828     0.006630
# Speed_limit                                          0.139938    -0.016105
# Junction_Control                                    -0.030077     0.003030
# 2nd_Road_Class                                      -0.029593     0.005604
# 2nd_Road_Number                                      0.000879     0.001723
# Pedestrian_Crossing-Human_Control                    0.008896     0.001844
# Pedestrian_Crossing-Physical_Facilities             -0.031188     0.008060
# Light_Conditions                                     0.028988     0.011530
# Weather_Conditions                                  -0.017772     0.004949
# Road_Surface_Conditions                             -0.044450     0.005299
# Urban_or_Rural_Area                                  0.120434    -0.015590
# Year                                                -0.001501    -0.004568
#
#                                          1st_Road_Class  1st_Road_Number  \
# Longitude                                     -0.055530        -0.078792
# Latitude                                       0.020079         0.036216
# Police_Force                                   0.035413        -0.004791
# Accident_Severity                              0.021280         0.000060
# Number_of_Vehicles                            -0.142221        -0.007516
# Number_of_Casualties                          -0.084650         0.010787
# Day_of_Week                                    0.009993         0.002174
# 1st_Road_Class                                 1.000000        -0.097588
# 1st_Road_Number                               -0.097588         1.000000
# Road_Type                                      0.377603         0.073159
# Speed_limit                                   -0.398476        -0.064232
# Junction_Control                               0.093173         0.030291
# 2nd_Road_Class                                 0.115269         0.039308
# 2nd_Road_Number                               -0.033613         0.183027
# Pedestrian_Crossing-Human_Control             -0.012718        -0.003659
# Pedestrian_Crossing-Physical_Facilities       -0.091990         0.035663
# Light_Conditions                              -0.019163         0.006971
# Weather_Conditions                             0.023274         0.007620
# Road_Surface_Conditions                        0.022625        -0.021010
# Urban_or_Rural_Area                           -0.240545        -0.014916
# Year                                          -0.003975         0.003601
#
#                                          Road_Type    ...     \
# Longitude                                -0.009731    ...
# Latitude                                  0.002674    ...
# Police_Force                             -0.005843    ...
# Accident_Severity                        -0.013443    ...
# Number_of_Vehicles                       -0.097474    ...
# Number_of_Casualties                     -0.044828    ...
# Day_of_Week                               0.006630    ...
# 1st_Road_Class                            0.377603    ...
# 1st_Road_Number                           0.073159    ...
# Road_Type                                 1.000000    ...
# Speed_limit                              -0.324674    ...
# Junction_Control                          0.116385    ...
# 2nd_Road_Class                            0.117982    ...
# 2nd_Road_Number                          -0.012576    ...
# Pedestrian_Crossing-Human_Control        -0.008067    ...
# Pedestrian_Crossing-Physical_Facilities  -0.053346    ...
# Light_Conditions                         -0.023598    ...
# Weather_Conditions                        0.017752    ...
# Road_Surface_Conditions                   0.006993    ...
# Urban_or_Rural_Area                      -0.080666    ...
# Year                                     -0.000381    ...
#
#                                          Junction_Control  2nd_Road_Class  \
# Longitude                                        0.047362        0.030071
# Latitude                                        -0.010469       -0.005766
# Police_Force                                    -0.099266       -0.112062
# Accident_Severity                                0.071285        0.068744
# Number_of_Vehicles                               0.075496        0.067805
# Number_of_Casualties                            -0.030077       -0.029593
# Day_of_Week                                      0.003030        0.005604
# 1st_Road_Class                                   0.093173        0.115269
# 1st_Road_Number                                  0.030291        0.039308
# Road_Type                                        0.116385        0.117982
# Speed_limit                                     -0.267717       -0.332436
# Junction_Control                                 1.000000        0.896007
# 2nd_Road_Class                                   0.896007        1.000000
# 2nd_Road_Number                                  0.199921        0.164272
# Pedestrian_Crossing-Human_Control               -0.013858       -0.020210
# Pedestrian_Crossing-Physical_Facilities          0.024532        0.147918
# Light_Conditions                                -0.016306       -0.001657
# Weather_Conditions                              -0.006029       -0.009045
# Road_Surface_Conditions                          0.027509        0.027123
# Urban_or_Rural_Area                             -0.220955       -0.292920
# Year                                            -0.003586       -0.002065
#
#                                          2nd_Road_Number  \
# Longitude                                       0.017780
# Latitude                                        0.000009
# Police_Force                                   -0.017549
# Accident_Severity                               0.030478
# Number_of_Vehicles                              0.025885
# Number_of_Casualties                            0.000879
# Day_of_Week                                     0.001723
# 1st_Road_Class                                 -0.033613
# 1st_Road_Number                                 0.183027
# Road_Type                                      -0.012576
# Speed_limit                                    -0.057357
# Junction_Control                                0.199921
# 2nd_Road_Class                                  0.164272
# 2nd_Road_Number                                 1.000000
# Pedestrian_Crossing-Human_Control              -0.002872
# Pedestrian_Crossing-Physical_Facilities         0.086292
# Light_Conditions                                0.007658
# Weather_Conditions                              0.004993
# Road_Surface_Conditions                         0.004405
# Urban_or_Rural_Area                            -0.045469
# Year                                           -0.000528
#
#                                          Pedestrian_Crossing-Human_Control  \
# Longitude                                                         0.026105
# Latitude                                                         -0.031831
# Police_Force                                                     -0.031681
# Accident_Severity                                                -0.009381
# Number_of_Vehicles                                                0.021641
# Number_of_Casualties                                              0.008896
# Day_of_Week                                                       0.001844
# 1st_Road_Class                                                   -0.012718
# 1st_Road_Number                                                  -0.003659
# Road_Type                                                        -0.008067
# Speed_limit                                                       0.041112
# Junction_Control                                                 -0.013858
# 2nd_Road_Class                                                   -0.020210
# 2nd_Road_Number                                                  -0.002872
# Pedestrian_Crossing-Human_Control                                 1.000000
# Pedestrian_Crossing-Physical_Facilities                          -0.085879
# Light_Conditions                                                  0.015873
# Weather_Conditions                                               -0.002444
# Road_Surface_Conditions                                          -0.002484
# Urban_or_Rural_Area                                               0.034119
# Year                                                             -0.001421
#
#                                          Pedestrian_Crossing-Physical_Facilities  \
# Longitude                                                               0.045955
# Latitude                                                                0.006558
# Police_Force                                                           -0.077739
# Accident_Severity                                                       0.013191
# Number_of_Vehicles                                                     -0.053470
# Number_of_Casualties                                                   -0.031188
# Day_of_Week                                                             0.008060
# 1st_Road_Class                                                         -0.091990
# 1st_Road_Number                                                         0.035663
# Road_Type                                                              -0.053346
# Speed_limit                                                            -0.218212
# Junction_Control                                                        0.024532
# 2nd_Road_Class                                                          0.147918
# 2nd_Road_Number                                                         0.086292
# Pedestrian_Crossing-Human_Control                                      -0.085879
# Pedestrian_Crossing-Physical_Facilities                                 1.000000
# Light_Conditions                                                        0.042640
# Weather_Conditions                                                     -0.015151
# Road_Surface_Conditions                                                 0.022940
# Urban_or_Rural_Area                                                    -0.250410
# Year                                                                   -0.003435
#
#                                          Light_Conditions  Weather_Conditions  \
# Longitude                                        0.021086           -0.006493
# Latitude                                         0.009720           -0.016755
# Police_Force                                    -0.023567            0.027885
# Accident_Severity                               -0.055661            0.013345
# Number_of_Vehicles                              -0.070242           -0.013091
# Number_of_Casualties                             0.028988           -0.017772
# Day_of_Week                                      0.011530            0.004949
# 1st_Road_Class                                  -0.019163            0.023274
# 1st_Road_Number                                  0.006971            0.007620
# Road_Type                                       -0.023598            0.017752
# Speed_limit                                     -0.042915           -0.006722
# Junction_Control                                -0.016306           -0.006029
# 2nd_Road_Class                                  -0.001657           -0.009045
# 2nd_Road_Number                                  0.007658            0.004993
# Pedestrian_Crossing-Human_Control                0.015873           -0.002444
# Pedestrian_Crossing-Physical_Facilities          0.042640           -0.015151
# Light_Conditions                                 1.000000            0.020465
# Weather_Conditions                               0.020465            1.000000
# Road_Surface_Conditions                         -0.143013            0.059835
# Urban_or_Rural_Area                             -0.060262            0.003853
# Year                                            -0.005251            0.005150
#
#                                          Road_Surface_Conditions  \
# Longitude                                               0.071014
# Latitude                                               -0.047321
# Police_Force                                           -0.055041
# Accident_Severity                                      -0.002434
# Number_of_Vehicles                                     -0.010377
# Number_of_Casualties                                   -0.044450
# Day_of_Week                                             0.005299
# 1st_Road_Class                                          0.022625
# 1st_Road_Number                                        -0.021010
# Road_Type                                               0.006993
# Speed_limit                                            -0.083605
# Junction_Control                                        0.027509
# 2nd_Road_Class                                          0.027123
# 2nd_Road_Number                                         0.004405
# Pedestrian_Crossing-Human_Control                      -0.002484
# Pedestrian_Crossing-Physical_Facilities                 0.022940
# Light_Conditions                                       -0.143013
# Weather_Conditions                                      0.059835
# Road_Surface_Conditions                                 1.000000
# Urban_or_Rural_Area                                    -0.077354
# Year                                                   -0.002454
#
#                                          Urban_or_Rural_Area      Year
# Longitude                                          -0.078369 -0.001930
# Latitude                                            0.014127  0.002860
# Police_Force                                        0.232472  0.007567
# Accident_Severity                                  -0.082840 -0.008257
# Number_of_Vehicles                                  0.042068 -0.002009
# Number_of_Casualties                                0.120434 -0.001501
# Day_of_Week                                        -0.015590 -0.004568
# 1st_Road_Class                                     -0.240545 -0.003975
# 1st_Road_Number                                    -0.014916  0.003601
# Road_Type                                          -0.080666 -0.000381
# Speed_limit                                         0.687871 -0.000046
# Junction_Control                                   -0.220955 -0.003586
# 2nd_Road_Class                                     -0.292920 -0.002065
# 2nd_Road_Number                                    -0.045469 -0.000528
# Pedestrian_Crossing-Human_Control                   0.034119 -0.001421
# Pedestrian_Crossing-Physical_Facilities            -0.250410 -0.003435
# Light_Conditions                                   -0.060262 -0.005251
# Weather_Conditions                                  0.003853  0.005150
# Road_Surface_Conditions                            -0.077354 -0.002454
# Urban_or_Rural_Area                                 1.000000  0.005545
# Year                                                0.005545  1.000000
#
# [21 rows x 21 columns]

# %%
# %matplotlib inline
sns.lmplot(x="Light_Conditions", y="Number_of_Casualties", data=data)

# %%
test1 = pd.read_csv('accidents_2005_to_2007.csv')
test1=test1.fillna('')
sns.lmplot(x="Number_of_Vehicles", y="Number_of_Casualties", hue="Road_Surface_Conditions", data=test1)
# Out:
# C:\Users\GADKARI\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sns.lmplot(x="Accident_Severity", y="Number_of_Casualties", hue="Light_Conditions", data=test1)

# %%
g = sns.FacetGrid(data, col="Road_Surface_Conditions")
g.map(sns.regplot, "Light_Conditions", "Number_of_Casualties")

# %%
sns.lmplot(x="Speed_limit", y="Number_of_Casualties", data=data)

# %%
g = sns.FacetGrid(test1, col="Road_Surface_Conditions")
g.map(sns.regplot, "Speed_limit", "Number_of_Casualties")

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
sale_price=data["Number_of_Casualties"]
gross_sqft=data["Number_of_Vehicles"]
print(sale_price.shape,gross_sqft.shape)
# Out:
# (570011,) (570011,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(gross_sqft, sale_price, test_size=0.2, random_state=42)
X_trainsales = X_train[:, np.newaxis]# another way to convert vector to matrix
X_testsales = X_test[:, np.newaxis]
Y_trainsales = Y_train[:, np.newaxis]
Y_testsales = Y_test[:, np.newaxis]

# %%
regr = linear_model.LinearRegression()
regr.fit(X_trainsales, Y_trainsales)
y_pred = regr.predict(X_testsales)
plt.scatter(X_testsales, Y_testsales,  color='blue')
plt.plot(X_testsales, y_pred, color='red', linewidth=3)
plt.xticks(())
plt.yticks(())
plt.show()
print("Coefficeints, the fitted model ",regr.coef_)
# Out:
# Coefficeints, the fitted model  [[ 0.25648829]]

# %% [markdown]
# ### Machine Learning

# %% [markdown]
# #### Classification

# %% [markdown]
# As show from the dataset utilized, it can be seen the data is categorized rather than quantified, and therefore, we selected the Decision-Tree model for classification. The taget in our dataset is the Accidet_Severity which could be: Fatal, Serious or Slight.

# %%
import matplotlib.patches as mpatches
from sklearn.tree import DecisionTreeClassifier
y = data.Accident_Severity

# %%
X = data[[
       'Road_Type', 'Speed_limit',
       'Junction_Control', 'Light_Conditions',
       'Weather_Conditions', 'Road_Surface_Conditions']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (427508, 6) (142503, 6) (427508,) (142503,)

# %%
clf_1 = DecisionTreeClassifier().fit(X_train, y_train)
clf_2 = DecisionTreeClassifier().fit(X_test, y_test)
z1 = clf_1.predict(X_train)
z2 = clf_2.predict(X_test)
print(len(X_train), len(y_train), len(z1))
print(len(X_test), len(y_test), len(z2))
# Out:
# 427508 427508 427508
# 142503 142503 142503

# %%
X_train['target_actual'] = y_train
X_train['target_expected'] = z1
X_train.head()
# Out:
#         Road_Type  Speed_limit  Junction_Control  Light_Conditions  \
# 531060          4           30                 0                 1
# 532148          3           70                 2                 1
# 105801          4           30                 2                 1
# 450921          4           30                 1                 1
# 471723          4           60                 0                 3
#
#         Weather_Conditions  Road_Surface_Conditions  target_actual  \
# 531060                   2                        1              3
# 532148                   3                        3              3
# 105801                   2                        1              3
# 450921                   3                        3              3
# 471723                   2                        1              3
#
#         target_expected
# 531060                3
# 532148                3
# 105801                3
# 450921                3
# 471723                3

# %%
X_test['target_actual'] = y_test
X_test['target_expected'] = z2
X_test.head()
# Out:
#         Road_Type  Speed_limit  Junction_Control  Light_Conditions  \
# 443205          4           30                 2                 4
# 479134          1           40                 1                 4
# 13182           4           30                 2                 1
# 253175          4           60                 0                 4
# 504862          4           30                 2                 4
#
#         Weather_Conditions  Road_Surface_Conditions  target_actual  \
# 443205                   3                        3              3
# 479134                   2                        1              2
# 13182                    3                        3              3
# 253175                   3                        1              3
# 504862                   3                        3              3
#
#         target_expected  result
# 443205                3       1
# 479134                3       0
# 13182                 3       1
# 253175                3       1
# 504862                3       1

# %%
print(len(X_test))
X_test['result'] = np.where(X_test['target_actual'] == X_test['target_expected'] 
                     , 1, 0)
X_test.head()
# Out:
# 142503
#         Road_Type  Speed_limit  Junction_Control  Light_Conditions  \
# 443205          4           30                 2                 4
# 479134          1           40                 1                 4
# 13182           4           30                 2                 1
# 253175          4           60                 0                 4
# 504862          4           30                 2                 4
#
#         Weather_Conditions  Road_Surface_Conditions  target_actual  \
# 443205                   3                        3              3
# 479134                   2                        1              2
# 13182                    3                        3              3
# 253175                   3                        1              3
# 504862                   3                        3              3
#
#         target_expected  result
# 443205                3       1
# 479134                3       0
# 13182                 3       1
# 253175                3       1
# 504862                3       1

# %% [markdown]
# ### Prediction Error percentage between actual and predicted

# %%
X_test.result.astype(int)
count_false=len(X_test[(X_test['result']==0)])
count_true=len(X_test[(X_test['result']==1)])
Size=len(X_test)
PerPreErr=(count_false/Size)*100
print('false=',count_false,'\ntrue=',count_true,'\nSize=',Size)
print('Prediction Error=',format(round(PerPreErr,2)),'%')
# Out:
# false= 20615
# true= 121888
# Size= 142503
# Prediction Error= 14.47 %

# %% [markdown]
# ##### Trying to balance between the train and test datasets

# %%
size=0.4
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=size)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

clf_1 = DecisionTreeClassifier().fit(X_train, y_train)
clf_2 = DecisionTreeClassifier().fit(X_test, y_test)
z1 = clf_1.predict(X_train)
z2 = clf_2.predict(X_test)


X_train['target_actual'] = y_train
X_train['target_expected'] = z1
X_train.head()

X_test['target_actual'] = y_test
X_test['target_expected'] = z2



X_test['result'] = np.where(X_test['target_actual'] == X_test['target_expected'] 
                     , 1, 0)


X_test.result.astype(int)
count_false=len(X_test[(X_test['result']==0)])
count_true=len(X_test[(X_test['result']==1)])
Size=len(X_test)
PerPreErr=(count_false/Size)*100
print('false=',count_false,'\ntrue=',count_true,'\nSize=',Size)
print('Prediction Error=',format(round(PerPreErr,2)),'%')
# Out:
# (342006, 6) (228005, 6) (342006,) (228005,)
# false= 33184
# true= 194821
# Size= 228005
# Prediction Error= 14.55 %

# %% [markdown]
# ## Linear Regression Model

# %% [markdown]
# In the previous section, the classification has been performed using the Decision-Tree model based on the assumption that our data is categorized rather than quantified, however, we have created a new dataset that aggregates; counting the number of accidents, our data according to different attribute, where our target (class) is the number of fatal accidents. This section will test using the Linear regression classification model as it will be shown.

# %%
from sklearn.linear_model import LinearRegression
# Create a LinearRegression Object
lreg = LinearRegression()

# %%
# Working on the most expectedly affecting features
df_Accidents_Fatal=data[(data.Accident_Severity==1)]
df_Accidents_Fatal=df_Accidents_Fatal[[
       'Road_Type', 'Speed_limit',
       'Junction_Control', 'Light_Conditions',
       'Weather_Conditions', 'Road_Surface_Conditions']]


df_Accidents_Fatal.head()
# Out:
#        Road_Type  Speed_limit  Junction_Control  Light_Conditions  \
# 824            2           30                 2                 1
# 16252          4           30                 1                 1
# 17413          4           30                 1                 1
# 17415          4           30                 2                 1
# 17420          4           30                 2                 1
#
#        Weather_Conditions  Road_Surface_Conditions
# 824                     3                        3
# 16252                   3                        3
# 17413                   3                        1
# 17415                   3                        3
# 17420                   3                        3

# %% [markdown]
# Aggregating our data grouped by the chosen features and create a new dataframe. Notice that target refers to the number (count) of accidents according to the group by function

# %%
def highlight_t(s):
    return ['background-color: orange' for v in s]

df_Fatal_ML=pd.DataFrame(df_Accidents_Fatal.groupby(['Road_Type', 'Speed_limit','Junction_Control', 'Light_Conditions','Weather_Conditions', 'Road_Surface_Conditions']).size().reset_index(name = "Target"))
df_Fatal_ML.head().style.apply(highlight_t,subset=['Target'])
# Out:
# <style  type="text/css" >
#     #T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row0_col6 {
#             background-color:  orange;
#         }    #T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row1_col6 {
#             background-color:  orange;
#         }    #T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row2_col6 {
#             background-color:  orange;
#         }    #T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row3_col6 {
#             background-color:  orange;
#         }    #T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row4_col6 {
#             background-color:  orange;
#         }</style>
# <table id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Road_Type</th>
#         <th class="col_heading level0 col1" >Speed_limit</th>
#         <th class="col_heading level0 col2" >Junction_Control</th>
#         <th class="col_heading level0 col3" >Light_Conditions</th>
#         <th class="col_heading level0 col4" >Weather_Conditions</th>
#         <th class="col_heading level0 col5" >Road_Surface_Conditions</th>
#         <th class="col_heading level0 col6" >Target</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row0_col0" class="data row0 col0" >1</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row0_col1" class="data row0 col1" >20</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row0_col2" class="data row0 col2" >0</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row0_col3" class="data row0 col3" >4</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row0_col4" class="data row0 col4" >3</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row0_col5" class="data row0 col5" >3</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row0_col6" class="data row0 col6" >1</td>
#     </tr>    <tr>
#         <th id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row1_col0" class="data row1 col0" >1</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row1_col1" class="data row1 col1" >30</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row1_col2" class="data row1 col2" >0</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row1_col3" class="data row1 col3" >1</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row1_col4" class="data row1 col4" >2</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row1_col5" class="data row1 col5" >1</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row1_col6" class="data row1 col6" >3</td>
#     </tr>    <tr>
#         <th id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row2_col0" class="data row2 col0" >1</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row2_col1" class="data row2 col1" >30</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row2_col2" class="data row2 col2" >0</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row2_col3" class="data row2 col3" >1</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row2_col4" class="data row2 col4" >3</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row2_col5" class="data row2 col5" >1</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row2_col6" class="data row2 col6" >5</td>
#     </tr>    <tr>
#         <th id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row3_col0" class="data row3 col0" >1</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row3_col1" class="data row3 col1" >30</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row3_col2" class="data row3 col2" >0</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row3_col3" class="data row3 col3" >1</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row3_col4" class="data row3 col4" >3</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row3_col5" class="data row3 col5" >3</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row3_col6" class="data row3 col6" >44</td>
#     </tr>    <tr>
#         <th id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row4_col0" class="data row4 col0" >1</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row4_col1" class="data row4 col1" >30</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row4_col2" class="data row4 col2" >0</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row4_col3" class="data row4 col3" >1</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row4_col4" class="data row4 col4" >6</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row4_col5" class="data row4 col5" >3</td>
#         <td id="T_676bff86_48da_11e8_98f0_84a6c8dbfdb6row4_col6" class="data row4 col6" >1</td>
#     </tr></tbody>
# </table>

# %%
sns.lmplot('Road_Type','Target',data = df_Fatal_ML)

# %% [markdown]
# Despite the reported statistical significance of the determined  β  values, it does not appear that a linear decision boundary exists to separate the two classes. This is not surprising, given that the majority of the predictors are qualitative and the few that are quantitative do not have much variation. Intuitively, I would not expect a linear decision boundary capable of linearly separating so many categorical predictors

# %%
# Data Columns
X_multi = df_Fatal_ML.drop('Target',1)

# Targets
Y_target = df_Fatal_ML.Target

# Implement Linear Regression
lreg.fit(X_multi,Y_target)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(' The estimated intercept coefficient is %.2f ' %lreg.intercept_)

print(' The number of coefficients used was %d ' % len(lreg.coef_))
# Out:
#  The estimated intercept coefficient is 25.30
#  The number of coefficients used was 6

# %%
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: orange' if v else '' for v in is_max]


# Set a DataFrame from the Features
coeff_df = pd.DataFrame(df_Fatal_ML.columns)
coeff_df.columns = ['Features']

# Set a new column lining up the coefficients from the linear regression
coeff_df["Coefficient Estimate"] = pd.Series(lreg.coef_)
# Show
coeff_df.style.apply(highlight_max,subset=['Coefficient Estimate'])
# Out:
# <style  type="text/css" >
#     #T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6row5_col1 {
#             background-color:  orange;
#         }</style>
# <table id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Features</th>
#         <th class="col_heading level0 col1" >Coefficient Estimate</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6row0_col0" class="data row0 col0" >Road_Type</td>
#         <td id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6row0_col1" class="data row0 col1" >1.83112</td>
#     </tr>    <tr>
#         <th id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6row1_col0" class="data row1 col0" >Speed_limit</td>
#         <td id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6row1_col1" class="data row1 col1" >0.100622</td>
#     </tr>    <tr>
#         <th id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6row2_col0" class="data row2 col0" >Junction_Control</td>
#         <td id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6row2_col1" class="data row2 col1" >-4.16962</td>
#     </tr>    <tr>
#         <th id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6row3_col0" class="data row3 col0" >Light_Conditions</td>
#         <td id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6row3_col1" class="data row3 col1" >-3.80914</td>
#     </tr>    <tr>
#         <th id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6row4_col0" class="data row4 col0" >Weather_Conditions</td>
#         <td id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6row4_col1" class="data row4 col1" >-3.24688</td>
#     </tr>    <tr>
#         <th id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6row5_col0" class="data row5 col0" >Road_Surface_Conditions</td>
#         <td id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6row5_col1" class="data row5 col1" >2.41126</td>
#     </tr>    <tr>
#         <th id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6row6_col0" class="data row6 col0" >Target</td>
#         <td id="T_b3d0b550_48da_11e8_a488_84a6c8dbfdb6row6_col1" class="data row6 col1" >nan</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ### Training and Validation

# %%
# Grab the output and set as X and Y test and train data sets!
#X_train, X_test, Y_train, Y_test = sklearn.cross_validation.train_test_split(X,df_Fatal_ML.Target)

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_multi,df_Fatal_ML.Target)
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (483, 6) (162, 6) (483,) (162,)

# %%
lreg = LinearRegression()

# Once again do a linear regression, except only on the training sets this time
lreg.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Predictions on training and testing sets
pred_train = lreg.predict(X_train)
pred_test = lreg.predict(X_test)

# %%
print("Fit a model X_train, and calculate MSE with Y_train: %.2f"  % np.mean((Y_train - pred_train) ** 2))
    
print("Fit a model X_train, and calculate MSE with X_test and Y_test: %.2f"  %np.mean((Y_test - pred_test) ** 2))
# Out:
# Fit a model X_train, and calculate MSE with Y_train: 3759.49
# Fit a model X_train, and calculate MSE with X_test and Y_test: 2150.46

# %% [markdown]
# ### Residual Plots

# %%
# Scatter plot the training data
train = plt.scatter(pred_train,(Y_train-pred_train),c='b',alpha=0.5)

# Scatter plot the testing data
test = plt.scatter(pred_test,(Y_test-pred_test),c='r',alpha=0.5)

# Plot a horizontal axis line at 0
plt.hlines(y=0,xmin=-10,xmax=50)

#Labels
plt.legend((train,test),('Training','Test'),loc='lower left')
plt.title('Residual Plots')
# Out:
# Text(0.5,1,'Residual Plots')

# %%
# Residual plot of all the dataset using seaborn
sns.residplot('Road_Type', 'Target', data = df_Fatal_ML)

# %% [markdown]
# ### K-NN

# %%
X_new = data[['Speed_limit', 'Urban_or_Rural_Area']]

# %%
Y_new = data.Year

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_new, Y_new, test_size=0.2, random_state=42)
X_trainsales = X_train
X_testsales = X_test
Y_trainsales = Y_train[:, np.newaxis]
Y_testsales = Y_test[:, np.newaxis]
k = 3
knn = KNeighborsClassifier(n_neighbors=k)
accuracy = cross_val_score(knn, X_trainsales, Y_train, cv=10, scoring='accuracy')

# %%
print (accuracy)
# Out:
# [ 0.34641025  0.33355993  0.32991974  0.3351023   0.3319664   0.32731738
#   0.3452193   0.34600877  0.34609649  0.33805566]

# %%
accuracy_array_data = []
karray_data = []
for k in range(3,10,2):
    knn = KNeighborsClassifier(n_neighbors=k)
    accuracy = cross_val_score(knn, X_trainsales, Y_train, cv=10, scoring='accuracy')
    accuracy_array_data.append(accuracy.mean())
    karray_data.append(k)

# %%
class_error = 1.0 - np.array(accuracy_array_data)
plt.plot(karray_data, class_error)
plt.xlabel('K')
plt.ylabel('Classification Error')
plt.show()
minimumind = np.argmin(class_error)
OptimumK = karray_data[minimumind]
print ("Optimal K is %d " %  OptimumK)

# %%
# Use Optimal value of K for test set
knn = KNeighborsClassifier(n_neighbors=OptimumK)

# fitting the model
knn.fit(X_trainsales, Y_train)

# predict
pred = knn.predict(X_testsales)

# evaluate accuracy
print(accuracy_score(Y_test, pred))

# %%
plt.plot(karray_data)
plt.ylabel('mean_squared_error_value')
plt.show()

# %%
plt.plot(class_error)
plt.ylabel('mean_squared_error_value')
plt.show()

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn import linear_model

# %%
X_log = data.Accident_Severity
Y_log = data[['Urban_or_Rural_Area', 'Speed_limit']]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(Y_log, X_log, test_size=0.2, random_state=42)
X_trainsales = X_train
X_testsales = X_test
Y_trainsales = Y_train[:, np.newaxis]
Y_testsales = Y_test[:, np.newaxis]

# %%
logistic = linear_model.LogisticRegression()
mdl = logistic.fit(X_trainsales, Y_trainsales)

# %%
print('LogisticRegression score: %f'
      % logistic.fit(X_trainsales, Y_trainsales).score(X_testsales, Y_testsales))
# Out:
# LogisticRegression score: 0.855749

# %%
knn = neighbors.KNeighborsClassifier()
print('KNN score: %f' % knn.fit(X_trainsales, Y_trainsales).score(X_testsales, Y_testsales))
# Out:
# KNN score: 0.855749

# %%
'''from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
vectorizer = TfidfVectorizer()

# %%
'''X_conf=data[['Urban_or_Rural_Area', 'Police_Force']]

y_conf=df.Did_Police_Officer_Attend_Scene_of_Accident

# %%
'''X_train, X_test, y_train, y_test = train_test_split(X_conf, y_conf, random_state=0)

# Run classifier, using a model that is too regularized (C too low) to see
# the impact on the results


#TK = vectorizer.fit_transform(X_train)
clf = MultinomialNB()

# %%
'''clf.fit(X_train, y_train)
labels = clf.predict(X_test)
target_names=['Urban_or_Rural_Area', 'Police_Force']
